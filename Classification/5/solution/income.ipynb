# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# درآمد
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این تمرین قصد داریم درخت تصمیمی بسازیم که قادر باشد با دریافت یک سری ویژگی‌های شخصی و شغلی از شهروندان آمریکایی پیش‌بینی کند آیا شخص درآمد سالانه‌ی بالای ۵۰ هزار دلار خواهد داشت یا خیر. مجموعه‌داده‌ی مورداستفاده و صورت مسئله بسیار خوش‌تعریف است، با این حال جهت پیش‌پردازش مناسب ویژگی‌ها و همچنین دست‌یابی به یک مدل  با عملکرد بالا نیاز است از تکنیک‌های مختلف مهندسی ویژگی و فوت‌و‌فن‌های مرتبط با درخت تصمیم که در درسنامه‌ها آموخته‌اید استفاده کنید. بهره‌گیری از این تکنیک‌ها جهت مواجهه با چالش‌های عملی می‌تواند به‌خوبی شما را برای استفاده از این مدل در دنیای واقعی آماده کند.‌
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     هر نمونه از این مجموعه‌داده با ویژگی‌هایی که در جدول زیر شرح داده شده همراه است. ستون <code>income</code> متغیر هدف مسئله است که درآمد شخص را نشان می‌دهد.
# </font>
# </p>
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |age|سن|
# |workclass|یک عبارت کلی که نشان‌دهنده‌ی وضعیت شغلی فرد است.|
# |fnlwgt|وزن نهایی، به عبارت دیگر تعداد افرادی که سرشماری باور دارد این ردیف بازنمایی می‌کند (نماینده‌ی آنهاست). |
# |education|بیشترین سطح تحصیلات فرد |
# |education.num|بیشترین سطح تحصیلات فرد به شکل عددی |
# |marital.status|وضعیت تاهل فرد. توجه شود که <code>Married-­civ-­spouse</code> به معنی همسر غیرنظامی و <code>Married-­AF-­spouse</code> به معنی همسر نظامی است.|
# |occupation|نوع کلی شغل یک فرد |
# |relationship|رابطه‌ی این فرد با دیگران، به عنوان مثال همسر (<code>Husband</code>). هر داده تنها دارای یک رابطه است. |
# |race|نژاد |
# |sex| جنسیت بیولوژیکی فرد |
# |capital.gain|سود سرمایه‌ی فرد  |
# |capital.loss| زیان سرمایه‌ی فرد |
# |hours.per.week| ساعت‌هایی که فرد گزارش داده در یک هفته کار می‌کند. |
# |native.country| سرزمین مادری |
# |income|درآمد، کمتر یا مساوی ۵۰ هزار دلار (<code dir=ltr><=50K</code>) یا بیشتر از آن (<code dir=ltr>>50K</code>) |
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train.csv</code> و نمونه‌های آزمون که باید دسته‌ی آن‌ها را پیش‌بینی کنید در فایل <code>test.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از مجموعه‌ی آموزشی را به عنوان مجموعه‌ی اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hahmadi\Desktop\Hossein John\Machine learning\Practices\Machine-Learning\Classification\5\solution

# %%
train_data = pd.read_csv('../income/income/data/train.csv')
train_data
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       40  Self-emp-not-inc  223881   Prof-school             15
# 1       30           Private  149118       HS-grad              9
# 2       46           Private  109209  Some-college             10
# 3       32           Private  229566     Assoc-voc             11
# 4       54                 ?  148657     Preschool              1
# ...    ...               ...     ...           ...            ...
# 24995   40           Private  130834  Some-college             10
# 24996   31         Local-gov   33124     Bachelors             13
# 24997   38       Federal-gov  190895     Bachelors             13
# 24998   23           Private  420973     Bachelors             13
# 24999   60           Private   88055          10th              6
#
#            marital.status        occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Prof-specialty        Husband  White    Male
# 1                Divorced      Craft-repair  Not-in-family  White  Female
# 2      Married-civ-spouse      Adm-clerical        Husband  White    Male
# 3      Married-civ-spouse     Other-service        Husband  White    Male
# 4      Married-civ-spouse                 ?           Wife  White  Female
# ...                   ...               ...            ...    ...     ...
# 24995       Never-married      Adm-clerical  Not-in-family  White  Female
# 24996       Never-married    Prof-specialty  Not-in-family  White  Female
# 24997  Married-civ-spouse    Prof-specialty        Husband  White    Male
# 24998       Never-married    Prof-specialty  Not-in-family  White  Female
# 24999  Married-civ-spouse  Transport-moving        Husband  White    Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 0             99999             0              70  United-States   >50K
# 1                 0             0              40  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3                 0             0              60  United-States   >50K
# 4                 0             0              40         Mexico  <=50K
# ...             ...           ...             ...            ...    ...
# 24995             0             0              40  United-States  <=50K
# 24996             0             0              50  United-States  <=50K
# 24997             0             0              40              ?   >50K
# 24998             0             0              40  United-States  <=50K
# 24999             0             0              40  United-States  <=50K
#
# [25000 rows x 15 columns]

# %%
test_data = pd.read_csv('../income/income/data/test.csv')
test_data
# Out:
#       age         workclass  fnlwgt     education  education.num  \
# 0      31           Private  176711       HS-grad              9
# 1      40           Private  120277  Some-college             10
# 2      43           Private  299197  Some-college             10
# 3      70      Self-emp-inc  188260       HS-grad              9
# 4      51           Private  254211     Bachelors             13
# ...   ...               ...     ...           ...            ...
# 7159   37  Self-emp-not-inc   75050     Assoc-voc             11
# 7160   36           Private  156780       HS-grad              9
# 7161   34           Private  381153       HS-grad              9
# 7162   59           Private  294395       Masters             14
# 7163   24         State-gov  506329  Some-college             10
#
#           marital.status        occupation    relationship  \
# 0     Married-civ-spouse  Transport-moving         Husband
# 1          Never-married             Sales   Not-in-family
# 2     Married-civ-spouse      Adm-clerical         Husband
# 3     Married-civ-spouse   Exec-managerial         Husband
# 4     Married-civ-spouse      Craft-repair         Husband
# ...                  ...               ...             ...
# 7159  Married-civ-spouse      Craft-repair         Husband
# 7160       Never-married             Sales  Other-relative
# 7161  Married-civ-spouse  Transport-moving         Husband
# 7162             Widowed    Prof-specialty   Not-in-family
# 7163       Never-married      Adm-clerical       Own-child
#
#                     race     sex  capital.gain  capital.loss  hours.per.week  \
# 0                  White    Male             0             0              38
# 1                  White    Male             0             0              40
# 2                  White    Male             0             0              40
# 3                  White    Male             0             0              16
# 4                  White    Male             0             0              20
# ...                  ...     ...           ...           ...             ...
# 7159               White    Male             0             0              55
# 7160  Asian-Pac-Islander  Female             0             0              40
# 7161               White    Male             0             0              40
# 7162               White  Female             0             0              40
# 7163  Asian-Pac-Islander    Male             0             0              40
#
#      native.country
# 0     United-States
# 1     United-States
# 2     United-States
# 3     United-States
# 4     United-States
# ...             ...
# 7159  United-States
# 7160              ?
# 7161  United-States
# 7162  United-States
# 7163              ?
#
# [7164 rows x 14 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید. توجه داشته باشید که انتخاب شما در بخش بعدی یعنی مدل‌سازی می‌تواند مراحلی که در این بخش طی می‌کنید را تحت تاثیر قرار دهد. بنابراین پیشنهاد می‌کنیم مواردی همچون مدیریت مقادیر گم‌شده، ویژگی‌های دسته‌ای و غیره را پس از مطالعه‌ی بخش بعد انجام دهید.
#     <br>
#     تکنیک‌هایی که در این بخش استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     پیش از هر چیز مجموعه‌داده را از نظر توازن بررسی کنیم. طبق کد پایین متوجه خواهیم شد که این مجموعه‌داده به‌شدت نامتوازن است و باید از تکنیک‌های مختلفی که در درسنامه‌ی مجموعه‌داده‌ی نامتوازن آموخته‌ایم استفاده کنیم تا به مدلی با عملکرد پایدارتر و بهتر دست یابیم. ما فعلاً تغییری در مجموعه‌داده نخواهیم داد و توازن را در هنگام مدل‌سازی رعایت خواهیم کرد.
#     </i>
# </font>
# </p>

# %%
train_data['income'].value_counts()
# Out:
# income
# <=50K    18955
# >50K      6045
# Name: count, dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     حال به‌صورت کلی نگاهی به ویژگی‌ها بی‌اندازیم و نوع آن‌ها و تعداد مقادیر یکتای آن‌ها را بررسی کنیم.
#     </i>
# </font>
# </p>

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25000 non-null  int64
#  1   workclass       25000 non-null  object
#  2   fnlwgt          25000 non-null  int64
#  3   education       25000 non-null  object
#  4   education.num   25000 non-null  int64
#  5   marital.status  25000 non-null  object
#  6   occupation      25000 non-null  object
#  7   relationship    25000 non-null  object
#  8   race            25000 non-null  object
#  9   sex             25000 non-null  object
#  10  capital.gain    25000 non-null  int64
#  11  capital.loss    25000 non-null  int64
#  12  hours.per.week  25000 non-null  int64
#  13  native.country  25000 non-null  object
#  14  income          25000 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.9+ MB

# %%
train_data.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            17876
# education            16
# education.num        16
# marital.status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital.gain        117
# capital.loss         90
# hours.per.week       93
# native.country       41
# income                2
# dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اگر کمی دقت کرده باشید دو ویژگی <code>education</code> و <code>education.num</code> در واقع نشانگر یک ویژگی هستند. بنابراین می‌توانیم ستون <code>education</code> را که از نوع دسته‌ای هست حذف کرده و تنها ستون <code>education.num</code> را که به‌صورت عددی است نگه داریم.
#     </i>
# </font>
# </p>

# %%
train_data = train_data.drop(columns=['education'])
test_data = test_data.drop(columns=['education'])

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اما وقت آن رسیده که مقادیر گم‌شده‌ی این مجموعه‌داده را مورد بررسی قرار دهیم. برای این کار ابتدا به کمک کد زیر تعداد مقادیر گم‌شده‌ی هر ستون را بررسی می‌کنیم.
#     </i>
# </font>
# </p>

# %%
train_data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     شاید با توجه به نتایج بالا فکر کنید پس این مجموعه‌داده شامل مقادیر گم‌شده نیست اما اگر کمی مجموعه‌داده را بررسی کنید متوجه خواهید شد که برخی مقادیر با علامت <code>?</code> ذخیره شده‌اند. بنابراین مقادیر گم‌شده در این مجموعه‌داده با علامت سوال نشان داده شده و بهتر است که این مقادیر را به <code>NaN</code> تبدیل کنیم تا بتوانیم مقادیر گم‌شده را به شکلی متعارف مدیریت کنیم.
#     </i>
# </font>
# </p>

# %%
train_data[4:5]
# Out:
#    age workclass  fnlwgt  education.num      marital.status occupation  \
# 4   54         ?  148657              1  Married-civ-spouse          ?
#
#   relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 4         Wife  White  Female             0             0              40
#
#   native.country income
# 4         Mexico  <=50K

# %%
train_data = train_data.replace('?', np.NaN)
test_data = test_data.replace('?', np.NaN)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اکنون بررسی کنیم چه تعداد مقادیر کدام ستون‌ها گم‌شده‌اند تا بتوانیم آن‌ها را مدیریت کنیم. توجه داشته باشید که در مجموعه‌داده‌‌ی آزمون هم برخی مقادیر گم‌شده وجود دارد.
#     </i>
# </font>
# </p>

# %%
train_data.isnull().sum()
# Out:
# age                  0
# workclass         1429
# fnlwgt               0
# education.num        0
# marital.status       0
# occupation        1434
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     437
# income               0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# age                 0
# workclass         387
# fnlwgt              0
# education.num       0
# marital.status      0
# occupation        389
# relationship        0
# race                0
# sex                 0
# capital.gain        0
# capital.loss        0
# hours.per.week      0
# native.country    138
# dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#    اگر از کتابخانه‌ی <code>H2O</code> استفاده کنیم نیازی نیست تا خودمان به‌صورت دستی مقادیر گم‌شده را مدیریت کنیم و درخت تصمیم این کتابخانه مستقیماً از این نوع مقادیر پشتیبانی می‌کند.
#     <br>
#     اما اگر از <code>scikit-learn</code> استفاده کنیم جهت مدیریت مقادیر گم‌شده توجه به اینکه ویژگی‌هایی که شامل مقادیر گم‌شده هستند از نوع دسته‌ای هستند یکی از ساده‌ترین روش‌ها این است که آن‌ها را با پرتکرارترین مقدار (دسته) پُر کنیم. در کد زیر ابتدا پرتکرارترین دسته‌ی ویژگی را پیدا کرده سپس تمام مقادیر <code>NaN</code> آن ویژگی را هم در مجموعه‌ی آموزشی و هم آزمون را با این دسته جایگزین می‌کنیم. توجه شود که برای پیدا کردن پرتکرارترین دسته تنها از مجموعه‌ی آموزشی استفاده کرده‌ایم و آن را به مجموعه‌ی آزمون تعمیم داده‌ایم. از آن جهت که در این راه‌حل هر دو کتابخانه را امتحان خواهیم کرد، تغییرات مربوط به <code>scikit-learn</code> را در دو دیتافریم کپی‌شده اعمال می‌کنیم.
#     </i>
# </font>
# </p>

# %%
sk_train = train_data.copy()
sk_test = test_data.copy()

# %%
cols = ['workclass', 'occupation', 'native.country']

for col in cols:
    most_frequent = sk_train[col].value_counts().sort_values(ascending=False).index[0]
    sk_train[col].fillna(most_frequent, inplace=True)
    sk_test[col].fillna(most_frequent, inplace=True)
    print('All the missing values in column', col, 'are replaced with', most_frequent)
# Out:
# All the missing values in column workclass are replaced with Private
# All the missing values in column occupation are replaced with Prof-specialty
# All the missing values in column native.country are replaced with United-States
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_train[col].fillna(most_frequent, inplace=True)
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_test[col].fillna(most_frequent, inplace=True)
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_train[col].fillna(most_frequent, inplace=True)
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_test[col].fillna(most_frequent, inplace=True)
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_train[col].fillna(most_frequent, inplace=True)
# C:\Users\hahmadi\AppData\Local\Temp\ipykernel_15024\1264143828.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sk_test[col].fillna(most_frequent, inplace=True)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     حال به سراغ مدیریت ویژگی‌های دسته‌ای می‌رویم.
#     باز هم اگر از کتابخانه‌ی <code>H2O</code> استفاده کنیم نیازی به مدیریت دستی ویژگی‌های دسته‌ای نداریم و این کتابخانه مستقیماً از ویژگی‌های دسته‌ای پشتیبانی می‌کند.
# اما از آنجا که کتابخانه‌ی <code>scikit-learn</code> از مقادیر دسته‌ای پشتیبانی نمی‌کند نیاز است تا آن‌ها را به کمک روش‌هایی که در فصل مهندسی ویژگی آموختیم به مقادیر عددی تبدیل کنیم. در ابتدا ستون <code>income</code> را که همان متغیر هدف است به کمک <code>LabelEncoder</code> به برچسب‌های عددی تبدیل می‌کنیم.
#     </i>
# </font>
# </p>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
sk_train['income'] = le.fit_transform(sk_train['income'])
to_label = dict(zip(le.classes_, le.transform(le.classes_)))
to_class = dict(zip(le.transform(le.classes_), le.classes_))
print(to_label)
# Out:
# {'<=50K': 0, '>50K': 1}

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     حال باید درباره سایر ویژگی‌های دسته‌ای تصمیم بگیریم. ساده‌ترین راه این است که به هر دسته یک عدد اختصاص دهیم و دسته‌ها را با این اعداد جایگزین کنیم. هرچند که این روش معایب خود را دارد اما به دلیل آن‌که قصد نداریم از روشی مانند One-Hot استفاده کرده و تعداد ویژگی‌ها را به شدت افزایش دهیم، به کمک تابع <code>OrdinalEncoder</code> از همین تکنیک استفاده خواهیم کرد. توجه داشته باشید که در نمونه‌های آزمون ممکن است دسته‌ای وجود داشته باشد که در هنگام آموزش آن را ندیده باشید. بنابراین می‌توانیم آرگومان <code>handle_unknown</code> را برابر <code>'use_encoded_value'</code> قرار دهید تا به جای این دسته‌ها مقداری که برای <code>unknown_value</code> تنظیم می‌کنید در نظر گرفته شود. برای این آرگومان می‌توانیم مقدار <code dir=ltr>-1</code> را در نظر بگیریم.
#     </i>
# </font>
# </p>

# %%
from sklearn.preprocessing import OrdinalEncoder

categorical_cols = sk_train.select_dtypes(include = "object").columns

enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

sk_train[categorical_cols] = enc.fit_transform(sk_train[categorical_cols])
sk_test[categorical_cols] = enc.transform(sk_test[categorical_cols])

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     یکبار دیگر ستون‌های مجموعه‌های خود را بررسی می‌کنیم تا از تبدیل نوع آن‌ها مطمئن شویم.
#     </i>
# </font>
# </p>

# %%
sk_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             25000 non-null  int64
#  1   workclass       25000 non-null  float64
#  2   fnlwgt          25000 non-null  int64
#  3   education.num   25000 non-null  int64
#  4   marital.status  25000 non-null  float64
#  5   occupation      25000 non-null  float64
#  6   relationship    25000 non-null  float64
#  7   race            25000 non-null  float64
#  8   sex             25000 non-null  float64
#  9   capital.gain    25000 non-null  int64
#  10  capital.loss    25000 non-null  int64
#  11  hours.per.week  25000 non-null  int64
#  12  native.country  25000 non-null  float64
#  13  income          25000 non-null  int32
# dtypes: float64(7), int32(1), int64(6)
# memory usage: 2.6 MB

# %%
sk_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7164 entries, 0 to 7163
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             7164 non-null   int64
#  1   workclass       7164 non-null   float64
#  2   fnlwgt          7164 non-null   int64
#  3   education.num   7164 non-null   int64
#  4   marital.status  7164 non-null   float64
#  5   occupation      7164 non-null   float64
#  6   relationship    7164 non-null   float64
#  7   race            7164 non-null   float64
#  8   sex             7164 non-null   float64
#  9   capital.gain    7164 non-null   int64
#  10  capital.loss    7164 non-null   int64
#  11  hours.per.week  7164 non-null   int64
#  12  native.country  7164 non-null   float64
# dtypes: float64(7), int64(6)
# memory usage: 727.7 KB

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     حال ستون متغیر هدف را از ویژگی‌ها جدا می‌کنیم تا بتوانیم به عنوان ورودی به مدل خود بدهیم.
#     </i>
# </font>
# </p>

# %%
sk_label = sk_train['income']
sk_train = sk_train.drop(columns=['income'])

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند. در این تمرین انتخاب کتابخانه‌ای که درخت تصمیم را در اختیارتان بگذارد به عهده‌ی خود شماست. می‌توانید همچون همیشه از کتابخانه‌ی <code>scikit-learn</code> استفاده کنید اما توجه داشته باشید که درخت تصمیم این کتابخانه از قابلیت‌های مهمی مثل مدیریت مستقیم مقادیر گم‌شده و ویژگی‌های دسته‌ای پشتیبانی نمی‌کند و نیاز خواهید داشت که مراحل پیش‌پردازش مختلفی را انجام دهید. اما پیشنهاد بهتر این است که با توجه به توضیحاتی که در ادامه خواهیم داد از کتابخانه‌ی <code>H2O</code> استفاده کنید که از قابلیت‌های ذکرشده پشتیبانی می‌کند و نیازی به طی کردن مراحل اضافی نیست (البته معمولاً عملکرد درخت تصمیم این کتابخانه هم بهتر از درخت تصمیم <code>scikit-learn</code> است). با این حال ما مقدار آستانه‌ی پاس شدن این تمرین را به‌گونه‌ای تنظیم کرده‌ایم که متعادل باشد و با هر دو روش بتوانید امتیاز موردنظر را کسب کنید. حتی می‌توانید خفن‌تر (😎) عمل کرده و با هرکدام از کتابخانه‌ها درخت تصمیمی بسازید و عملکرد آن‌ها را مقایسه کنید.
# </font>
# </p>

# %% [markdown]
# <h3 align=right style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#     استفاده از <code>scikit-learn</code>
# </font>
# </h3>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     به منظور استفاده از درخت تصمیم برای مسائل دسته‌بندی می‌توانید از <code>DecisionTreeClassifier</code> موجود در کتابخانه‌ی <code>scikit-learn</code> استفاده کنید. نحوه‌ی آموزش مدل و پیش‌بینی برای نمونه‌های جدید همچون تمام مدل‌های این کتابخانه است، اما برخی پارامترها و آرگومان‌های بسیار کاربردی این کلاس در جدول زیر شرح داده شده‌اند. جهت بررسی پارامترها و توضیحات بیشتر می‌توانید از <a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier" target="__blank">این لینک</a>، سند اصلی آن را مطالعه کنید.
# </font>
# </p>
#
# <center>
# <p dir=ltr style="direction: ltr; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <code dir=ltr>from sklearn.tree import DecisionTreeClassifier</code>
#     <br>
#     <code dir=ltr>clf = DecisionTreeClassifier()</code>
# </font>
# </p>
# </center>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |پارامتر|توضیحات|مقادیر ممکن|مقدار پیش‌فرض|
# |:------:|:---:|:---:|:---:|
# |<code>criterion</code>|معیار ارزیابی تفکیک (معیار ناخالصی یا بهره اطلاعاتی)|<code>"gini"</code>، <code>"entropy"</code> یا <code>"log_loss"</code>|<code>"gini"</code>|
# |<code>max_depth</code>|حداکثر عمق درخت|عدد <code>int</code>|<code>None</code>|
# |<code>min_samples_split</code>|حداقل نمونه‌ها جهت تفکیک یک گره‌ی داخلی|عدد <code>int</code> (تعداد) یا <code>float</code> (درصد)|<code>2</code>|
# |<code>min_samples_leaf</code>|حداقل نمونه‌های یک برگ. یک گره تنها در صورتی تفکیک می‌یابد که هرکدام از شاخه‌های راست و چپ آن حداقل شامل این تعداد نمونه باشد|عدد <code>int</code> (تعداد) یا <code>float</code> (درصد)|<code>1</code>|
# |<code>max_features</code>|تعداد ویژگی‌هایی که در هنگام جستجوی بهترین تفکیک بررسی می‌شوند|عدد <code>int</code> (تعداد)، <code>float</code> (درصد)، ، <code>"sqrt"</code> (جذر)، <code>"log2"</code> (لگاریتم در مبنای ۲) یا <code>None</code> (تمام ویژگی‌ها)|<code>None</code>|
# |<code>min_impurity_decrease</code>|یک گره هنگامی تفکیک می‌شود که آن تفکیک باعث کاهش ناخالصی بیشتر یا مساوی این مقدار شود|عدد <code>float</code>|<code>0.0</code>|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <b>نکته:</b>
#     پارامتر کاربردی دیگری به نام <code>ccp_alpha</code> وجود دارد که به منظور پس‌هرس درخت تصمیم با روش Minimal Cost-Complexity استفاده می‌شود. از آنجا که شرح این تکنیک خارج از بحث این فصل است، ضرورتی بر استفاده از آن تعریف نشده است. اما در صورت علاقه می‌توانید برای مطالعه‌ی این روش جذاب به بخش <a href="https://scikit-learn.org/stable/modules/tree.html#minimal-cost-complexity-pruning" target="__blank">معرفی آن</a> در <code>scikit-learn</code> یا فصل سوم کتاب <i>Classification and Regression Trees</i> نوشته‌ی <i>Leo Breiman</i> مراجعه کرده و یا به شکلی ساده‌تر و جذاب‌تر <a href="https://youtu.be/D0efHEJsfHo" target="__blank">این ویدیو</a> را از <i>StatQuest</i> مشاهده کنید.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اگر مدل را <code>clf</code> بنامیم، پس از آموزش آن می‌توانید به کمک توابع یا متغیرهای زیر، برخی ویژگی‌های مهم درخت تصمیم را مورد بررسی قرار دهید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |پارامتر|توضیحات|
# |:------:|:---:|
# | <code dir=ltr>clf.get_depth()</code> | عمق درخت |
# | <code dir=ltr>clf.get_n_leaves()</code> | تعداد برگ‌های درخت |
# | <code dir=ltr>clf.feature_names_in_</code> | ویژگی‌های ورودی |
# | <code dir=ltr>clf.feature_importances_</code> | اهمیت هر ویژگی طبق معیار ناخالصی |
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     همچنین طبق کد زیر می‌توانید به کمک تابع <code>plot_tree</code> درخت تصمیم خود را ترسیم کنید. البته در صورتی‌که درخت حاصل بزرگ باشد ترسیم آن چندان جالب به نظر نخواهد رسید.
# </font>
# </p>
#
# <center>
# <p dir=ltr style="direction: ltr; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <code dir=ltr>from sklearn import tree</code>
#     <br>
#     <code dir=ltr>tree.plot_tree(clf)</code>
# </font>
# </p>
# </center>

# %% [markdown]
# <h3 align=right style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#     استفاده از <code>H2O</code>
# </font>
# </h3>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در کتابخانه‌ی <code>H2O</code> درخت تصمیم به‌صورت مشخص پیاده‌سازی نشده اما به کمک ترفندی که شرح خواهیم داد می‌توانید به یک درخت تصمیم دست یابید. در این کتابخانه مدل‌های حرفه‌ای‌تری پیاده‌سازی شده که در واقع اساس آن‌ها درخت تصمیم است. یکی از این مدل‌ها «<i>جنگل تصادفی</i>» نام دارد که در این کتابخانه با نام <code>H2ORandomForestEstimator</code> در دسترس است و در فصل یادگیری تجمعی کاملاً با ساختار آن آشنا خواهید شد. این مدل در واقع متشکل از تعداد زیادی درخت تصمیم است. بنابراین اگر ما یک جنگل تصادفی بسازیم که تنها شامل یک درخت باشد  در واقع مدل همانند یک درخت تصمیم عمل خواهد کرد. البته نیاز است به شکل زیر برخی از پارامترهای آن را به گونه‌ای مقداردهی کنیم که رفتاری شبیه به درخت تصمیم داشته باشد.
# </font>
# </p>
#
# <center>
# <p dir=ltr style="direction: ltr; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# <code>from h2o.estimators import H2ORandomForestEstimator</code>
# <br>
# <code>model = H2ORandomForestEstimator(ntrees=1, sample_rate=1)</code>
# </font>
# </p>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برخی از پارامترهای کاربردی این کلاس نیز در جدول زیر معرفی و شرح داده شده است. جهت بررسی پارامترها و توضیحات بیشتر می‌توانید از <a href="https://docs.h2o.ai/h2o/latest-stable/h2o-docs/data-science/drf.html" target="__blank">این لینک</a>، سند اصلی آن را مطالعه کنید.
# </font>
# </p>
#
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |پارامتر|توضیحات|مقادیر ممکن|مقدار پیش‌فرض|
# |:------:|:-----:|:---:|:---:|
# |<code>mtries</code>|تعداد ویژگی‌هایی که به‌صورت تصادفی در هر سطح برای جستجوی بهترین تفکیک استفاده می‌شود| <code dir=ltr>-1</code> برای جذر، <code dir=ltr>-2</code> برای تمام ویژگی‌ها یا عدد بزرگتر یا مساوی <code>1</code> |<code dir=ltr>-1</code>|
# |<code>max_depth</code>|حداکثر عمق درخت|عدد <code>int</code>|<code>20</code>|
# |<code>min_rows</code>|حداقل نمونه‌های یک برگ. یک گره تنها در صورتی تفکیک می‌یابد که هرکدام از شاخه‌های راست و چپ آن حداقل شامل این تعداد نمونه باشد|عدد <code>int</code>|<code>1</code>|
# |<code>min_split_improvement</code>|یک گره هنگامی تفکیک می‌شود که کاهش مربعات خطا حداقل به این میزان بهبود یابد|عدد کوچک (پیشنهاد می‌شود در بازه‌ی <code>1e-10</code> تا <code>1e-3</code> باشد)|<code>1e-05</code>|
# |<code>categorical_encoding</code>|رویکرد مدیریت ویژگی‌های دسته‌ای|<code>"auto"</code> (به‌صورت پیش‌فرض معادل <code>"enum"</code>)، <code>"enum"</code> (پشتیبانی مستقیم از ویژگی دسته‌ای)، <code>"one_hot_explicit"</code> (کدگذاری one-hot)،  <code>"binary"</code> (کدگذاری باینری)، <code>"label_encoder"</code> (برچسب‌گذاری) و غیره|<code>"auto"</code>|
# |<code>balance_classes</code>|متوازن‌سازی مجموعه‌داده به کمک نمونه‌افزایی کلاس اقلیت|<code>True</code> یا <code>False</code>|<code>False</code>|
# |<code>nfolds</code>|تعداد قطعه‌ها در اعتبارسنجی متقاطع (cross-validation)|عدد <code>int</code>|<code>0</code>|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای استفاده از <code>H2O</code> پیش از هرچیز نیاز است مراحل راه‌اندازی آن را که در درسنامه‌ی مربوط به این کتابخانه شرح داده شد اجرا کرده باشید و همچنین دیتافریم‌های خود را به <code>H2OFrame</code> تبدیل کرده باشید. پس از آن می‌توانید به کمک مدل معرفی‌شده در بالا پارامترهای موردنظر خود را مقداردهی کنید. سپس جهت آموزش مدل نیاز است تابع <code dir=ltr>fit()</code> را با سه آرگومان مهم زیر صدا بزنید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |پارامتر|توضیحات|
# |:------:|:-----:|
# |<code>x</code>| لیستی شامل نام ستون‌های ورودی (ویژگی‌ها) |
# |<code>y</code>| نام ستون متغیر هدف |
# |<code>training_frame</code>| داده‌های آموزشی از جنس <code>H2OFrame</code> |
# |<code>validation_frame</code>| داده‌های اعتبارسنجی از جنس <code>H2OFrame</code> (دلخواه)|
#
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     جهت پیش‌بینی نیز می‌توانید <code>H2OFrame</code> موردنظر خود را به تابع <code dir=ltr>predict()</code> بدهید تا مدل شروع به پیش‌بینی متغیر هدف برای نمونه‌های موردنظر شما کند. توجه داشته باشید که اگر قصد دارید مقادیر پیش‌بینی‌شده را به یک دیتافریم <code>pandas</code> تبدیل کنید می‌توانید از تابع <code dir=ltr>as_data_frame()</code> استفاده کنید. مقادیر پیش‌بینی‌شده در ستونی به نام <code>predict</code> در دیتافریم به‌دست‌آمده ذخیره شده‌اند.
# </font>
# </p>

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون وقت آن رسیده که با توجه به کتابخانه‌ی انتخابی، مدل را آموزش دهید.
# </font>
# </p>

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اگر قصد استفاده از کتابخانه‌ی <code>scikit-learn</code> را داشته باشیم می‌توانیم به شکل زیر یک مدل را تعریف کرده و آموزش دهیم. توجه داشته باشید که به کمک آرگومان <code>class_weight</code> وزن نمونه‌های اقلیت (برچسب <code dir=ltr>>50K</code>) را بیشتر از نمونه‌های اکثریت (<code dir=ltr><=50K</code>) در نظر گرفته‌ایم.
#     </i>
# </font>
# </p>

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=10, min_samples_split=50, min_samples_leaf=8, class_weight={0: 0.4, 1: 0.6})
clf.fit(sk_train, sk_label)
# Out:
# DecisionTreeClassifier(class_weight={0: 0.4, 1: 0.6}, max_depth=10,
#                        min_samples_leaf=8, min_samples_split=50)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     حال نگاهی به جزئیات درخت به‌دست‌آمده بی‌اندازیم.
#     </i>
# </font>
# </p>

# %%
print('-- Details of the acheived Decision Tree --')
print('Depth:', clf.get_depth())
print('Number of leaves:', clf.get_n_leaves())
print('\n--Feature importances --')
for feature, importance in sorted(zip(clf.feature_names_in_, clf.feature_importances_), key=lambda x: x[1], reverse=True):
    print(feature, '\t' ,importance)
# Out:
# -- Details of the acheived Decision Tree --
# Depth: 10
# Number of leaves: 180
#
# --Feature importances --
# relationship 	 0.43944885070355144
# education.num 	 0.19631172110863795
# capital.gain 	 0.18977038686235218
# age 	 0.0585283471176681
# hours.per.week 	 0.04023360014305142
# capital.loss 	 0.037627180440160994
# workclass 	 0.010908859829024852
# fnlwgt 	 0.010649717742005252
# occupation 	 0.009686926761055148
# sex 	 0.002163325104005383
# race 	 0.0016995419209027073
# marital.status 	 0.001597570284263105
# native.country 	 0.0013739719833215256

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اگر هم قصد داشته باشیم از کتابخانه‌ی <code>H2O</code> استفاده کنیم ابتدا هسته‌ی آن را راه‌اندازی کرده و دیتافریم‌های خود را به <code>H2OFrame</code> تبدیل می‌کنیم.
#     </i>
# </font>
# </p>

# %%
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 17.0.12+8-LTS-286, mixed mode, sharing)
#   Starting server from C:\Users\hahmadi\Desktop\Hossein John\Machine learning\qenv\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\hahmadi\AppData\Local\Temp\tmp0dmrj5ch
#   JVM stdout: C:\Users\hahmadi\AppData\Local\Temp\tmp0dmrj5ch\h2o_HAHMADI_started_from_python.out
#   JVM stderr: C:\Users\hahmadi\AppData\Local\Temp\tmp0dmrj5ch\h2o_HAHMADI_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# Warning: Your H2O cluster version is too old (2 years, 3 months and 6 days)!Please download and install the latest version from http://h2o.ai/download/
# --------------------------  --------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Europe/Madrid
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    2 years, 3 months and 6 days !!!
# H2O_cluster_name:           H2O_from_python_HAHMADI_b2ndf9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.986 Gb
# H2O_cluster_total_cores:    0
# H2O_cluster_allowed_cores:  0
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.6 final
# --------------------------  --------------------------------

# %%
hf_train = h2o.H2OFrame(train_data)
hf_test = h2o.H2OFrame(test_data)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     سپس باید یک لیست از ویژگی‌ها بسازیم. برای این کار نام ستون‌های فریم‌ را گرفته و ستون هدف را از آن حذف می‌کنیم.
#     </i>
# </font>
# </p>

# %%
TARGET = 'income'
features = list(hf_train.columns)
features.remove(TARGET)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <i>
#     اکنون می‌توانیم پارامترهای موردنظر را مقداردهی کرده و مدل را آموزش دهیم. در اینجا با مقداردهی <code>True</code> به آرگومان <code>balance_classes</code> می‌توانیم از روش نمونه‌افزایی به کمک تکرار نمونه‌های اقلیت استفاده کنیم. البته این کتابخانه آرگومان‌های دیگری را جهت مدیریت توازن داده‌ها در اختیار شما قرار می‌دهد اما جهت حفظ سادگی از استفاده‌ی آن‌ها پرهیز کرده‌ایم.
#     </i>
# </font>
# </p>

# %%
from h2o.estimators import H2ORandomForestEstimator

model = H2ORandomForestEstimator(ntrees=1, sample_rate=1, mtries=-2, max_depth=10,
                                 min_rows=8, min_split_improvement=1e-4,
                                 balance_classes=True, nfolds=5)

model.train(x=features, y=TARGET, training_frame=hf_train)
# Out:
# drf Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1731188139590_1
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0                1.0                       1.0               3155.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0       10.0       10.0        10.0       234.0       234.0        234.0
# ModelMetricsBinomial: drf
# ** Reported on train data. **
#
# MSE: NaN
# RMSE: NaN
# LogLoss: NaN
# Mean Per-Class Error: NaN
# AUC: NaN
# AUCPR: NaN
# Gini: NaN
#
# ModelMetricsBinomial: drf
# ** Reported on cross-validation data. **
#
# MSE: 0.10257935352513176
# RMSE: 0.32028011728037653
# LogLoss: 0.5832852660260383
# Mean Per-Class Error: 0.18021846177409864
# AUC: 0.8951966947969364
# AUCPR: 0.7685767843556107
# Gini: 0.7903933895938728
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.325866504486349:
#             <=50K    >50K   Error               Rate
# 0  <=50K  15754.0  3201.0  0.1689   (3201.0/18955.0)
# 1   >50K   1158.0  4887.0  0.1916    (1158.0/6045.0)
# 2  Total  16912.0  8088.0  0.1744   (4359.0/25000.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.325867      0.691573  150.0
# 1                        max f2   0.134009      0.779462  262.0
# 2                  max f0point5   0.632066      0.718685   59.0
# 3                  max accuracy   0.549119      0.855240   78.0
# 4                 max precision   0.966871      0.965340    2.0
# 5                    max recall   0.000000      1.000000  399.0
# 6               max specificity   1.000000      0.997204    0.0
# 7              max absolute_mcc   0.325867      0.585363  150.0
# 8    max min_per_class_accuracy   0.305294      0.819520  164.0
# 9   max mean_per_class_accuracy   0.307848      0.820798  162.0
# 10                      max tns   1.000000  18902.000000    0.0
# 11                      max fns   1.000000   4569.000000    0.0
# 12                      max fps   0.000000  18955.000000  399.0
# 13                      max tps   0.000000   6045.000000  399.0
# 14                      max tnr   1.000000      0.997204    0.0
# 15                      max fnr   1.000000      0.755831    0.0
# 16                      max fpr   0.000000      1.000000  399.0
# 17                      max tpr   0.000000      1.000000  399.0
# Gains/Lift Table: Avg response rate: 24.18 %, avg score: 24.06 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                   0.06116         1.000000  3.992295
# 1       2                   0.10572         0.758096  3.085031
# 2       3                   0.15564         0.626775  2.614605
# 3       4                   0.20120         0.549119  2.294759
# 4       5                   0.30188         0.369964  1.567505
# 5       6                   0.40112         0.185734  1.048498
# 6       7                   0.50048         0.068770  0.601034
# 7       8                   0.60208         0.012674  0.276795
# 8       9                   0.70296         0.003129  0.055754
# 9      10                   0.80356         0.000525  0.014800
# 10     11                   1.00000         0.000000  0.134739
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          3.992295       0.965337  1.000000                  0.965337
# 1          3.609891       0.745961  0.795318                  0.872872
# 2          3.290663       0.632212  0.668955                  0.795682
# 3          3.065149       0.554873  0.574908                  0.741153
# 4          2.565670       0.379023  0.402073                  0.620379
# 5          2.190310       0.253527  0.272763                  0.529617
# 6          1.874792       0.145330  0.123138                  0.453325
# 7          1.605133       0.066929  0.036889                  0.388121
# 8          1.382786       0.013481  0.007485                  0.334358
# 9          1.211524       0.003579  0.001072                  0.292946
# 10         1.000000       0.032580  0.000000                  0.241800
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           1.000000      0.244169                 0.244169  299.229455
# 1           0.913728      0.137469                 0.381638  208.503103
# 2           0.835220      0.130521                 0.512159  161.460520
# 3           0.776275      0.104549                 0.616708  129.475887
# 4           0.651475      0.157816                 0.774524   56.750474
# 5           0.557779      0.104053                 0.878577    4.849795
# 6           0.471490      0.059719                 0.938296  -39.896562
# 7           0.398151      0.028122                 0.966419  -72.320457
# 8           0.342088      0.005624                 0.972043  -94.424581
# 9           0.299395      0.001489                 0.973532  -98.520046
# 10          0.240582      0.026468                 1.000000  -86.526087
#
#     cumulative_gain  kolmogorov_smirnov
# 0        299.229455            0.241373
# 1        260.989138            0.363912
# 2        229.066313            0.470217
# 3        206.514922            0.548019
# 4        156.566980            0.623377
# 5        119.031047            0.629725
# 6         87.479242            0.577441
# 7         60.513308            0.480531
# 8         38.278566            0.354897
# 9         21.152353            0.224178
# 10         0.000000            0.000000
# Cross-Validation Metrics Summary:
#                                    mean         sd  cv_1_valid  cv_2_valid  \
# 0                  accuracy    0.827371   0.004582    0.831896    0.832031
# 1                       auc    0.895195   0.005562    0.891133    0.904903
# 2                       err    0.172629   0.004582    0.168104    0.167970
# 3                 err_count  863.200000  25.665152  838.000000  838.000000
# 4                  f0point5    0.639315   0.014886    0.651672    0.653030
# 5                        f1    0.692685   0.011969    0.695936    0.710435
# 6                        f2    0.755957   0.013131    0.746652    0.778906
# 7            lift_top_group    3.995393   0.113882    4.010236    3.856609
# 8                   logloss    0.583325   0.022848    0.570183    0.589472
# 9       max_per_class_error    0.194980   0.018119    0.215221    0.168087
# 10                      mcc    0.587054   0.013250    0.589003    0.608556
# 11  mean_per_class_accuracy    0.819811   0.006988    0.815988    0.832151
# 12     mean_per_class_error    0.180189   0.006988    0.184012    0.167849
# 13                      mse    0.102578   0.002100    0.103657    0.098927
# 14                   pr_auc    0.768387   0.012379    0.770363    0.787087
# 15                precision    0.608132   0.017108    0.625163    0.619650
# 16                       r2    0.440209   0.017297    0.439826    0.468897
# 17                   recall    0.805115   0.018296    0.784779    0.832389
# 18                     rmse    0.320264   0.003298    0.321958    0.314526
# 19              specificity    0.834506   0.008466    0.847196    0.831913
#
#     cv_3_valid  cv_4_valid  cv_5_valid
# 0     0.822174    0.827227    0.823529
# 1     0.892422    0.894520    0.892996
# 2     0.177826    0.172773    0.176471
# 3   895.000000  863.000000  882.000000
# 4     0.622000    0.645119    0.624752
# 5     0.681834    0.693863    0.681358
# 6     0.754405    0.750576    0.749245
# 7     4.111873    3.902171    4.096076
# 8     0.554365    0.615314    0.587292
# 9     0.187976    0.206169    0.197447
# 10    0.576972    0.585121    0.575619
# 11    0.818655    0.815996    0.816265
# 12    0.181345    0.184004    0.183735
# 13    0.103148    0.104217    0.102941
# 14    0.757165    0.770322    0.757001
# 15    0.587623    0.616257    0.591965
# 16    0.425647    0.439125    0.427547
# 17    0.812024    0.793831    0.802553
# 18    0.321167    0.322827    0.320845
# 19    0.825286    0.838161    0.829976
# Scoring History:
#                timestamp    duration  number_of_trees  training_rmse  \
# 0    2024-11-09 22:35:44   1.442 sec              0.0            NaN
#
#    training_logloss  training_auc  training_pr_auc  training_lift  \
# 0               NaN           NaN              NaN            NaN
#
#    training_classification_error
# 0                            NaN
# Variable Importances:
#           variable  relative_importance  scaled_importance  percentage
# 0     relationship          2659.130127           1.000000    0.484302
# 1     capital.gain           837.049805           0.314783    0.152450
# 2       occupation           633.447754           0.238216    0.115369
# 3    education.num           482.990417           0.181635    0.087966
# 4              age           280.798431           0.105598    0.051141
# 5     capital.loss           179.315521           0.067434    0.032658
# 6   hours.per.week           174.145905           0.065490    0.031717
# 7   native.country           105.524788           0.039684    0.019219
# 8        workclass            61.907410           0.023281    0.011275
# 9   marital.status            39.572529           0.014882    0.007207
# 10             sex            15.632984           0.005879    0.002847
# 11          fnlwgt            13.703369           0.005153    0.002496
# 12            race             7.425520           0.002792    0.001352

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>F1-score</code> نام دارد و کلاس مثبت (<code>pos_label</code>) را معادل <code dir=ltr>>50K</code> فرض کرده‌ایم، به این معنی که مدل شما باید برای پیش‌بینی درست افراد پردرآمد عملکرد مناسبی داشته باشد.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه‌ی آموزش یا اعتبارسنجی ارزیابی کنید و طبق نتایج به‌دست‌آمده پارامترهای مدل خود را بهتر تنظیم کنید.
# </font>
# </p>

# %%
sklearn_train_pr = clf.predict(sk_train)
sklearn_train_pr
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
sklearn_train_pr = pd.Series(sklearn_train_pr)

# %%
sklearn_train_pr = sklearn_train_pr.apply(lambda x: ">50K" if x == 1 else "<=50K")
sklearn_train_pr
# Out:
# 0         >50K
# 1        <=50K
# 2         >50K
# 3        <=50K
# 4        <=50K
#          ...
# 24995    <=50K
# 24996    <=50K
# 24997     >50K
# 24998    <=50K
# 24999    <=50K
# Length: 25000, dtype: object

# %%
from sklearn.metrics import f1_score

sklearn_train_pr = clf.predict(sk_train)
sklearn_train_pr = [to_class[p] for p in sklearn_train_pr]
sklearn_test_pr = clf.predict(sk_test)
sklearn_test_pr = [to_class[p] for p in sklearn_test_pr]

h2o_train_pr = model.predict(hf_train)
h2o_test_pr = model.predict(hf_test)

print('Scikit-learn performance on training data:',
      f1_score(sklearn_train_pr, train_data['income'], pos_label='>50K'))

print('H2O performance on training data:',
      f1_score(h2o_train_pr.as_data_frame()['predict'], train_data['income'], pos_label='>50K'))
# Out:
# drf prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# drf prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# Scikit-learn performance on training data: 0.7134872417982989
# C:\Users\hahmadi\Desktop\Hossein John\Machine learning\qenv\lib\site-packages\h2o\job.py:83: UserWarning: Test/Validation dataset column 'native.country' has levels not trained on: ["Holand-Netherlands"]
#   warnings.warn(w)
# H2O performance on training data: 0.72

# %%
h2o_test_pr
# Out:
# <table>
# <thead>
# <tr><th>predict  </th><th style="text-align: right;">   &lt;=50K</th><th style="text-align: right;">     &gt;50K</th></tr>
# </thead>
# <tbody>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.771553</td><td style="text-align: right;">0.228447 </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">1       </td><td style="text-align: right;">0        </td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.472981</td><td style="text-align: right;">0.527019 </td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0.470501</td><td style="text-align: right;">0.529499 </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.762863</td><td style="text-align: right;">0.237137 </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.949672</td><td style="text-align: right;">0.0503284</td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">1       </td><td style="text-align: right;">0        </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.765202</td><td style="text-align: right;">0.234798 </td></tr>
# <tr><td>&lt;=50K    </td><td style="text-align: right;">0.676109</td><td style="text-align: right;">0.323891 </td></tr>
# <tr><td>&gt;50K     </td><td style="text-align: right;">0       </td><td style="text-align: right;">1        </td></tr>
# </tbody>
# </table>

# %%
h2o_train_pr.as_data_frame()
# Out:
#       predict     <=50K      >50K
# 0        >50K  0.000000  1.000000
# 1       <=50K  0.965902  0.034098
# 2        >50K  0.472981  0.527019
# 3       <=50K  0.771553  0.228447
# 4       <=50K  1.000000  0.000000
# ...       ...       ...       ...
# 24995   <=50K  0.987218  0.012782
# 24996   <=50K  0.877195  0.122805
# 24997    >50K  0.247200  0.752800
# 24998   <=50K  0.997019  0.002981
# 24999   <=50K  0.877752  0.122248
#
# [25000 rows x 3 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>66</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     پس از مهندسی ویژگی و مدل‌سازی، الگوریتمی دارید که می‌تواند شما را از متغیرهای وابسته به متغیر هدف برساند.
#     <br>
#     از این مدل برای پیش‌بینی نمونه‌های موجود در مجموعه‌ی آزمون استفاده کنید و نتایج را در یک دیتافریم تک‌ستونه با نام <code>submission</code> و در قالب زیر آماده کنید. توجه داشته باشید که ترتیب پیش‌بینی شما اهمیت دارد یعنی به عنوان مثال پیش‌بینی مدل برای نمونه‌ی آزمون <code>m</code>ام را باید در ردیف <code>m</code>ام این دیتافریم ذخیره کنید.
# </font>
# </p>

# %% [markdown]
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |income|پیش‌بینی مدل شما (مقدار <code dir=ltr>>50K</code> یا <code dir=ltr><=50K</code>)|
#
# </font>
# </div>
# </center>

# %%
submission = pd.DataFrame({'income': h2o_test_pr.as_data_frame()['predict']})

# %%
submission
# Out:
#      income
# 0     <=50K
# 1     <=50K
# 2      >50K
# 3     <=50K
# 4     <=50K
# ...     ...
# 7159  <=50K
# 7160  <=50K
# 7161  <=50K
# 7162  <=50K
# 7163  <=50K
#
# [7164 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['income.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['income.ipynb', 'submission.csv']

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>راهنمایی</b>
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ۱. توازن مجموعه‌داده را بررسی و مدیریت کنید.
#     <br>
#     ۲. برای مقادیر گم‌شده چه در هنگام آموزش و چه هنگام آزمون چاره‌ای بی‌اندیشید.
#     <br>
#     ۳. مقادیر گم‌شده ممکن است با عبارت دیگری به جز مقدار <code>NaN</code> نشان داده شده باشد.
#     <br>
#     ۴. ویژگی‌های دسته‌ای را به‌خوبی مدیریت کنید. توجه داشته باشید که ممکن است در هنگام آزمون با دسته‌ای مواجه شوید که در نمونه‌های آموزشی رخ نداده باشد.
#     <br>
#     ۵. برای تعیین حداکثر عمق درخت می‌توانید یکبار درخت را به شکل آزاد و کامل بسازید، سپس عمق آن را مشاهده کنید. سپس می‌توانید مقادیر کمتر از آن را برای حداکثر عمق آزمایش و تحلیل کنید.
#     <br>
#     ۶. برای ارزیابی مدل خود و کشف مدل بهتر می‌توانید بخشی از مجموعه‌داده را به عنوان مجموعه‌ی اعتبارسنجی جدا کنید یا اینکه از تکنیک‌های اعتبارسنجی متقاطع (cross-validation) و مانند آن کمک بگیرید.
# </font>
# </p>
