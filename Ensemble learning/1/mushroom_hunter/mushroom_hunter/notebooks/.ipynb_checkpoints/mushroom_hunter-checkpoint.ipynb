# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# شکارچی قارچ
# </font>
# </h1>
#
# <center>
# <img src="mushroom.jpg">
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     قارچ‌ها چندان اهل شوخی نیستند و اگر یکی از گونه‌های سمی آن را با نوع خوراکی اشتباه بگیرید خطر مرگ خواهد داشت! همان‌طور که هر چند وقت یکبار خبری از این دست را در کشور خودمان نیز می‌شنویم. به همین علت است که اصلاً توصیه نمی‌شود وقتی در دل طبیعت به قارچی برخوردید هوس خوردن آن را کنید. زیرا حتی اگر از قبل با برخی از گونه‌های سمی و خوراکی آشنا باشید هم آنقدر جزئیات زیاد است که تنها یک متخصص یا قارچ‌شناس قادر است با درجه‌ی اطمینان بالایی به تفکیک این گونه‌ها بپردازد. در این تمرین از یک مجموعه‌داده‌ی قارچی کمک خواهیم گرفت و الگوریتم جنگل تصادفی را روی آن اجرا می‌کنیم تا به مدلی دست یابیم که قادر باشد با دریافت چندین ویژگی از یک قارچ،‌ سمی یا خوراکی بودن آن را نتیجه‌گیری و اعلام کند. جالب است بدانید یک اصطلاح قدیمی برای عمل رفتن به طبیعت و جمع‌آوری قارچ‌ها (اکثراً با هدف خوراکی) وجود دارد که به آن <i>شکار قارچ (mushroom hunting)</i> می‌گویند. لازمه‌‌ی اینکه شخصی شکارچی قارچ شود این است که با گونه‌های مختلف آن آشنا باشد و بتواند به کمک دانش و تجربه‌ی خود براساس ویژگی‌های مختلف،‌ نوع قارچ را تشخیص دهد. اما مشاهده خواهید کرد تا انتهای این تمرین به مدلی دست خواهیم یافت که به‌صورت هوشمند و با دقت بیشتری از انسان قادر به انجام همین کار خواهد بود.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده‌ای که در این تمرین استفاده خواهیم کرد شامل نمونه‌هایی فرضی از ۲۳ گونه‌ی مختلف قارچ‌های تیغک‌دار است. هرکدام از این گونه‌ها به عنوان قطعاً خوراکی،‌ قطعاً سمی، عدم تشخیص خوراکی‌بودن و توصیه‌نشده شناخته شده‌اند. مواردی که قطعیتی برای آن وجود ندارد نیز در نهایت برچسب سمی خورده‌اند تا فقط دو کلاس خوراکی و سمی داشته باشیم. ویژگی‌هایی که برای هر قارچ استخراج و در نظر گرفته شده در جدول زیر آمده است. مقدار هر ویژگی بصورت مخفف در مجموعه‌داده ذخیره شده اما کلمات اصلی نظیر هر مخفف نیز در جدول قابل مطالعه است. توجه داشته باشید که در ستون <code>class</code> که همان ستون متغیر هدف ما است مقدار <code>e</code> به معنی خوراکی بودن و مقدار <code>p</code> به معنی سمی بودن است.
# </font>
# </p>
#
# <center>
# <img src="structure.jpg">
# </center>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|مقادیر و مخفف‌ها|
# |:------:|:---:|:------:|
# |cap-shape|شکل کلاهک| bell=b, conical=c, convex=x, flat=f, knobbed=k, sunken=s |
# |cap-surface|سطح کلاهک| fibrous=f, grooves=g, scaly=y, smooth=s |
# |cap-color|رنگ کلاهک| brown=n, buff=b, cinnamon=c, gray=g, green=r, pink=p, purple=u, red=e, white=w, yellow=y |
# |bruises|کبودی| bruises=t, no=f |
# |odor|عطر| almond=a, anise=l, creosote=c, fishy=y, foul=f, musty=m, none=n, pungent=p, spicy=s |
# |gill-attachment|چسبندگی تیغه| attached=a, descending=d, free=f, notched=n |
# |gill-spacing|فاصله تیغه| close=c, crowded=w, distant=d |
# |gill-size|اندازه تیغه| broad=b, narrow=n |
# |gill-color|رنگ تیغه| black=k, brown=n, buff=b, chocolate=h, gray=g, green=r, orange=o, pink=p, purple=u, red=e, white=w, yellow=y |
# |stalk-shape|شکل ساقه| enlarging=e, tapering=t |
# |stalk-root|ریشه ساقه| bulbous=b, club=c, cup=u, equal=e, rhizomorphs=z, rooted=r, missing=? |
# |stalk-surface-above-ring|سطح ریشه بالای حلقه| fibrous=f, scaly=y, silky=k, smooth=s |
# |stalk-surface-below-ring|سطح ریشه زیر حلقه| fibrous=f, scaly=y, silky=k, smooth=s |
# |stalk-color-above-ring|رنگ ریشه بالای حلقه| brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y |
# |stalk-color-below-ring|رنگ ریشه زیر حلقه| brown=n, buff=b, cinnamon=c, gray=g, orange=o, pink=p, red=e, white=w, yellow=y |
# |veil-type|نوع غشا| partial=p, universal=u |
# |veil-color|رنگ غشا| brown=n, orange=o, white=w, yellow=y |
# |ring-number|تعداد حلقه| none=n, one=o, two=t |
# |ring-type|نوع حلقه| cobwebby=c, evanescent=e, flaring=f, large=l, none=n, pendant=p, sheathing=s, zone=z |
# |spore-print-color|رنگ نقش هاگ| black=k, brown=n, buff=b, chocolate=h, green=r, orange=o, purple=u, white=w, yellow=y |
# |population|جمعیت| abundant=a, clustered=c, numerous=n, scattered=s, several=v, solitary=y |
# |habitat|زیست‌گاه| grasses=g, leaves=l, meadows=m, paths=p, urban=u, waste=w, woods=d |
# |class|گونه (برچسب)| edible=e, poisonous=p |
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانید. نمونه‌های آموزشی در فایل <code>train.csv</code> و نمونه‌های آزمون که باید دسته‌ی آن‌ها را پیش‌بینی کنید در فایل <code>test.csv</code> ذخیره شده‌اند. اگر لازم دانستید می‌توانید به دلخواه خود بخشی از مجموعه‌ی آموزشی را به عنوان مجموعه‌ی اعتبارسنجی نیز جدا کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train.csv')
train_data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        e         b           y         w       t    a               f
# 1        p         x           y         n       t    p               f
# 2        e         f           s         y       t    a               f
# 3        p         x           f         g       f    f               f
# 4        e         x           f         n       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 6494     p         x           y         g       f    f               f
# 6495     p         f           y         n       t    p               f
# 6496     e         x           s         w       f    n               f
# 6497     e         x           f         e       t    n               f
# 6498     p         f           s         b       t    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         b          w  ...                        s
# 1               c         n          n  ...                        s
# 2               w         n          w  ...                        s
# 3               c         b          h  ...                        k
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 6494            c         b          p  ...                        k
# 6495            c         n          k  ...                        s
# 6496            w         b          n  ...                        f
# 6497            c         b          w  ...                        s
# 6498            c         b          p  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         p                      p         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 6494                      p                      b         p          w
# 6495                      w                      w         p          w
# 6496                      w                      w         p          w
# 6497                      p                      p         p          w
# 6498                      w                      w         p          w
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       m
# 1              o         p                 k          s       u
# 2              o         p                 n          v       d
# 3              o         l                 h          v       g
# 4              o         e                 k          s       g
# ...          ...       ...               ...        ...     ...
# 6494           o         l                 h          v       d
# 6495           o         p                 k          s       g
# 6496           o         e                 n          a       g
# 6497           o         p                 n          v       d
# 6498           o         p                 h          s       g
#
# [6499 rows x 23 columns]

# %%
test_data =  pd.read_csv('../data/test.csv')
test_data
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           f         n       t    n               f
# 1            x           f         w       f    n               f
# 2            x           f         g       f    n               f
# 3            f           f         g       t    n               f
# 4            x           y         e       t    n               f
# ...        ...         ...       ...     ...  ...             ...
# 1620         k           y         n       f    f               f
# 1621         f           y         n       f    y               f
# 1622         x           y         g       f    f               f
# 1623         x           s         w       t    f               f
# 1624         x           s         w       t    p               f
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         b          p           t  ...
# 1               w         b          n           t  ...
# 2               w         b          n           t  ...
# 3               c         b          u           t  ...
# 4               c         b          n           t  ...
# ...           ...       ...        ...         ...  ...
# 1620            c         n          b           t  ...
# 1621            c         n          b           t  ...
# 1622            c         b          p           e  ...
# 1623            c         b          p           t  ...
# 1624            c         n          p           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      g                      p
# 1                           f                      w                      w
# 2                           s                      w                      w
# 3                           s                      g                      w
# 4                           s                      p                      p
# ...                       ...                    ...                    ...
# 1620                        k                      w                      p
# 1621                        s                      p                      w
# 1622                        k                      b                      n
# 1623                        s                      w                      w
# 1624                        s                      w                      w
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 0            p          w           o         p                 k          y
# 1            p          w           o         e                 k          a
# 2            p          w           o         e                 k          a
# 3            p          w           o         p                 n          y
# 4            p          w           o         p                 n          v
# ...        ...        ...         ...       ...               ...        ...
# 1620         p          w           o         e                 w          v
# 1621         p          w           o         e                 w          v
# 1622         p          w           o         l                 h          v
# 1623         p          w           o         p                 h          s
# 1624         p          w           o         p                 n          v
#
#      habitat
# 0          d
# 1          g
# 2          g
# 3          d
# 4          d
# ...      ...
# 1620       d
# 1621       p
# 1622       p
# 1623       u
# 1624       g
#
# [1625 rows x 22 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در این سوال شما می‌توانید از هر تکنیک پیش‌پردازش/مهندسی ویژگی که در فصل‌های گذشته آموختید، استفاده کنید.
#     <br>
#     تکنیک‌هایی که استفاده می‌کنید به شکل مستقیم مورد ارزیابی توسط سامانه داوری قرار <b>نمی‌گیرند.</b> بلکه همه آن‌ها در دقت مدل شما تاثیر خواهند گذاشت؛ بنابراین هر چه پیش‌پردازش/مهندسی ویژگی بهتری انجام دهید تا دقت مدل بهبود پیدا کند، امتیاز بیشتری از این سوال کسب خواهید کرد.
# </font>
# </p>

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6499 entries, 0 to 6498
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     6499 non-null   object
#  1   cap-shape                 6499 non-null   object
#  2   cap-surface               6499 non-null   object
#  3   cap-color                 6499 non-null   object
#  4   bruises                   6499 non-null   object
#  5   odor                      6499 non-null   object
#  6   gill-attachment           6499 non-null   object
#  7   gill-spacing              6499 non-null   object
#  8   gill-size                 6499 non-null   object
#  9   gill-color                6499 non-null   object
#  10  stalk-shape               6499 non-null   object
#  11  stalk-root                6499 non-null   object
#  12  stalk-surface-above-ring  6499 non-null   object
#  13  stalk-surface-below-ring  6499 non-null   object
#  14  stalk-color-above-ring    6499 non-null   object
#  15  stalk-color-below-ring    6499 non-null   object
#  16  veil-type                 6499 non-null   object
#  17  veil-color                6499 non-null   object
#  18  ring-number               6499 non-null   object
#  19  ring-type                 6499 non-null   object
#  20  spore-print-color         6499 non-null   object
#  21  population                6499 non-null   object
#  22  habitat                   6499 non-null   object
# dtypes: object(23)
# memory usage: 1.1+ MB

# %%
(train_data == '?').sum()
# Out:
# class                          0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  1976
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
train_data.drop('stalk-root', axis = 1, inplace = True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6499 entries, 0 to 6498
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     6499 non-null   object
#  1   cap-shape                 6499 non-null   object
#  2   cap-surface               6499 non-null   object
#  3   cap-color                 6499 non-null   object
#  4   bruises                   6499 non-null   object
#  5   odor                      6499 non-null   object
#  6   gill-attachment           6499 non-null   object
#  7   gill-spacing              6499 non-null   object
#  8   gill-size                 6499 non-null   object
#  9   gill-color                6499 non-null   object
#  10  stalk-shape               6499 non-null   object
#  11  stalk-surface-above-ring  6499 non-null   object
#  12  stalk-surface-below-ring  6499 non-null   object
#  13  stalk-color-above-ring    6499 non-null   object
#  14  stalk-color-below-ring    6499 non-null   object
#  15  veil-type                 6499 non-null   object
#  16  veil-color                6499 non-null   object
#  17  ring-number               6499 non-null   object
#  18  ring-type                 6499 non-null   object
#  19  spore-print-color         6499 non-null   object
#  20  population                6499 non-null   object
#  21  habitat                   6499 non-null   object
# dtypes: object(22)
# memory usage: 1.1+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1625 entries, 0 to 1624
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   cap-shape                 1625 non-null   object
#  1   cap-surface               1625 non-null   object
#  2   cap-color                 1625 non-null   object
#  3   bruises                   1625 non-null   object
#  4   odor                      1625 non-null   object
#  5   gill-attachment           1625 non-null   object
#  6   gill-spacing              1625 non-null   object
#  7   gill-size                 1625 non-null   object
#  8   gill-color                1625 non-null   object
#  9   stalk-shape               1625 non-null   object
#  10  stalk-root                1625 non-null   object
#  11  stalk-surface-above-ring  1625 non-null   object
#  12  stalk-surface-below-ring  1625 non-null   object
#  13  stalk-color-above-ring    1625 non-null   object
#  14  stalk-color-below-ring    1625 non-null   object
#  15  veil-type                 1625 non-null   object
#  16  veil-color                1625 non-null   object
#  17  ring-number               1625 non-null   object
#  18  ring-type                 1625 non-null   object
#  19  spore-print-color         1625 non-null   object
#  20  population                1625 non-null   object
#  21  habitat                   1625 non-null   object
# dtypes: object(22)
# memory usage: 279.4+ KB

# %%
(test_data == '?').sum()
# Out:
# cap-shape                     0
# cap-surface                   0
# cap-color                     0
# bruises                       0
# odor                          0
# gill-attachment               0
# gill-spacing                  0
# gill-size                     0
# gill-color                    0
# stalk-shape                   0
# stalk-root                  504
# stalk-surface-above-ring      0
# stalk-surface-below-ring      0
# stalk-color-above-ring        0
# stalk-color-below-ring        0
# veil-type                     0
# veil-color                    0
# ring-number                   0
# ring-type                     0
# spore-print-color             0
# population                    0
# habitat                       0
# dtype: int64

# %%
test_data.drop('stalk-root', axis = 1, inplace = True)

# %%
(test_data == '?').sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
train_data.drop('veil-type', axis = 1, inplace = True)

# %%
train_data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-surface-above-ring', 'stalk-surface-below-ring',
#        'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-color',
#        'ring-number', 'ring-type', 'spore-print-color', 'population',
#        'habitat'],
#       dtype='object')

# %%
test_data['veil-type'].value_counts()
# Out:
# veil-type
# p    1625
# Name: count, dtype: int64

# %%
test_data.drop('veil-type', axis = 1, inplace = True)

# %%
from sklearn.preprocessing import OrdinalEncoder
ol = OrdinalEncoder(categories = [['a', 'c', 'n', 's', 'v', 'y'],['n', 'o', 't']])
train_data[['population', 'ring-number']] = ol.fit_transform(train_data[['population', 'ring-number']]).astype(int)

# %%
train_data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     e         b           y         w       t    a               f
# 1     p         x           y         n       t    p               f
# 2     e         f           s         y       t    a               f
# 3     p         x           f         g       f    f               f
# 4     e         x           f         n       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         b          w  ...                        s
# 1            c         n          n  ...                        s
# 2            w         n          w  ...                        s
# 3            c         b          h  ...                        k
# 4            w         b          k  ...                        f
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# 1                        s                      w                      w
# 2                        s                      w                      w
# 3                        k                      p                      p
# 4                        s                      w                      w
#
#   veil-color ring-number  ring-type spore-print-color population  habitat
# 0          w           1          p                 k          3        m
# 1          w           1          p                 k          3        u
# 2          w           1          p                 n          4        d
# 3          w           1          l                 h          4        g
# 4          w           1          e                 k          3        g
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
ol = OrdinalEncoder(categories = [['a', 'c', 'n', 's', 'v', 'y'],['n', 'o', 't']])
test_data[['population', 'ring-number']] = ol.fit_transform(test_data[['population', 'ring-number']]).astype(int)

# %%
test_data.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           f         n       t    n               f            c
# 1         x           f         w       f    n               f            w
# 2         x           f         g       f    n               f            w
# 3         f           f         g       t    n               f            c
# 4         x           y         e       t    n               f            c
#
#   gill-size gill-color stalk-shape stalk-surface-above-ring  \
# 0         b          p           t                        s
# 1         b          n           t                        f
# 2         b          n           t                        f
# 3         b          u           t                        s
# 4         b          n           t                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      g                      p
# 1                        f                      w                      w
# 2                        s                      w                      w
# 3                        s                      g                      w
# 4                        s                      p                      p
#
#   veil-color  ring-number ring-type spore-print-color  population habitat
# 0          w            1         p                 k           5       d
# 1          w            1         e                 k           0       g
# 2          w            1         e                 k           0       g
# 3          w            1         p                 n           5       d
# 4          w            1         p                 n           4       d

# %%
train_data.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     e         b           y         w       t    a               f
# 1     p         x           y         n       t    p               f
# 2     e         f           s         y       t    a               f
# 3     p         x           f         g       f    f               f
# 4     e         x           f         n       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         b          w  ...                        s
# 1            c         n          n  ...                        s
# 2            w         n          w  ...                        s
# 3            c         b          h  ...                        k
# 4            w         b          k  ...                        f
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# 1                        s                      w                      w
# 2                        s                      w                      w
# 3                        k                      p                      p
# 4                        s                      w                      w
#
#   veil-color ring-number  ring-type spore-print-color population  habitat
# 0          w           1          p                 k          3        m
# 1          w           1          p                 k          3        u
# 2          w           1          p                 n          4        d
# 3          w           1          l                 h          4        g
# 4          w           1          e                 k          3        g
#
# [5 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in train_data.columns:
    if train_data[column].dtype == 'object': 
        train_data[column] = label_encoder.fit_transform(train_data[column])
        if column in test_data.columns:  
            test_data[column] = label_encoder.transform(test_data[column])

train_data.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      0          0            3          8        1     0                1
# 1      1          5            3          4        1     6                1
# 2      0          2            2          9        1     0                1
# 3      1          5            0          3        0     2                1
# 4      0          5            0          4        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          0          10  ...                         2
# 1             0          1           5  ...                         2
# 2             1          1          10  ...                         2
# 3             0          0           3  ...                         1
# 4             1          0           4  ...                         0
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         1                       6                       6
# 4                         2                       7                       7
#
#    veil-color  ring-number  ring-type  spore-print-color  population  habitat
# 0           2            1          4                  2           3        3
# 1           2            1          4                  2           3        5
# 2           2            1          4                  3           4        0
# 3           2            1          2                  1           4        1
# 4           2            1          0                  2           3        1
#
# [5 rows x 21 columns]

# %%
test_data.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            0          4        1     5                1
# 1          5            0          8        0     5                1
# 2          5            0          3        0     5                1
# 3          2            0          3        1     5                1
# 4          5            3          2        1     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  stalk-surface-above-ring  \
# 0             0          0           7            1                         2
# 1             1          0           5            1                         0
# 2             1          0           5            1                         0
# 3             0          0           9            1                         2
# 4             0          0           5            1                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       3                       6
# 1                         0                       7                       7
# 2                         2                       7                       7
# 3                         2                       3                       7
# 4                         2                       6                       6
#
#    veil-color  ring-number  ring-type  spore-print-color  population  habitat
# 0           2            1          4                  2           5        0
# 1           2            1          0                  2           0        1
# 2           2            1          0                  2           0        1
# 3           2            1          4                  3           5        0
# 4           2            1          4                  3           4        0

# %%
corr_matrix = train_data.corr().abs()
corr_matrix
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.049545     0.173824   0.040843
# cap-shape                 0.049545   1.000000     0.050648   0.052209
# cap-surface               0.173824   0.050648     1.000000   0.017293
# cap-color                 0.040843   0.052209     0.017293   1.000000
# bruises                   0.500526   0.033837     0.081183   0.006714
# odor                      0.089666   0.027230     0.042827   0.384914
# gill-attachment           0.128149   0.094725     0.035221   0.042563
# gill-spacing              0.345722   0.012769     0.286731   0.146975
# gill-size                 0.541694   0.050942     0.206543   0.166843
# gill-color                0.532084   0.002324     0.154629   0.077033
# stalk-shape               0.101164   0.068056     0.014540   0.453016
# stalk-surface-above-ring  0.331843   0.034613     0.097790   0.056089
# stalk-surface-below-ring  0.297424   0.034984     0.109499   0.046695
# stalk-color-above-ring    0.159512   0.026580     0.069993   0.004792
# stalk-color-below-ring    0.150008   0.031276     0.077399   0.004713
# veil-color                0.145333   0.084508     0.016855   0.036375
# ring-number               0.209939   0.105215     0.027691   0.007926
# ring-type                 0.416708   0.025194     0.097055   0.161881
# spore-print-color         0.173711   0.077272     0.227073   0.290393
# population                0.299936   0.072413     0.016860   0.155466
# habitat                   0.212959   0.040798     0.162217   0.030789
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                     0.500526  0.089666         0.128149      0.345722
# cap-shape                 0.033837  0.027230         0.094725      0.012769
# cap-surface               0.081183  0.042827         0.035221      0.286731
# cap-color                 0.006714  0.384914         0.042563      0.146975
# bruises                   1.000000  0.061789         0.139264      0.299538
# odor                      0.061789  1.000000         0.060089      0.063805
# gill-attachment           0.139264  0.060089         1.000000      0.071985
# gill-spacing              0.299538  0.063805         0.071985      1.000000
# gill-size                 0.366131  0.308160         0.109313      0.107365
# gill-color                0.526803  0.124263         0.131314      0.097173
# stalk-shape               0.095457  0.458082         0.186728      0.079519
# stalk-surface-above-ring  0.467305  0.114298         0.087950      0.216872
# stalk-surface-below-ring  0.464709  0.057511         0.117819      0.218085
# stalk-color-above-ring    0.090104  0.177887         0.100047      0.274687
# stalk-color-below-ring    0.095571  0.168892         0.098490      0.256164
# veil-color                0.121072  0.058230         0.896781      0.074462
# ring-number               0.051684  0.113845         0.095569      0.249754
# ring-type                 0.693453  0.276954         0.145763      0.191458
# spore-print-color         0.286756  0.465337         0.034735      0.050170
# population                0.089117  0.041468         0.172751      0.528504
# habitat                   0.086912  0.019540         0.031777      0.153027
#
#                           gill-size  gill-color  ...  \
# class                      0.541694    0.532084  ...
# cap-shape                  0.050942    0.002324  ...
# cap-surface                0.206543    0.154629  ...
# cap-color                  0.166843    0.077033  ...
# bruises                    0.366131    0.526803  ...
# odor                       0.308160    0.124263  ...
# gill-attachment            0.109313    0.131314  ...
# gill-spacing               0.107365    0.097173  ...
# gill-size                  1.000000    0.514602  ...
# gill-color                 0.514602    1.000000  ...
# stalk-shape                0.216303    0.169454  ...
# stalk-surface-above-ring   0.057176    0.226412  ...
# stalk-surface-below-ring   0.010199    0.258905  ...
# stalk-color-above-ring     0.297485    0.057599  ...
# stalk-color-below-ring     0.279056    0.071640  ...
# veil-color                 0.104510    0.097916  ...
# ring-number                0.173537    0.088361  ...
# ring-type                  0.459592    0.627636  ...
# spore-print-color          0.618708    0.417278  ...
# population                 0.147022    0.036907  ...
# habitat                    0.165091    0.212190  ...
#
#                           stalk-surface-above-ring  stalk-surface-below-ring  \
# class                                     0.331843                  0.297424
# cap-shape                                 0.034613                  0.034984
# cap-surface                               0.097790                  0.109499
# cap-color                                 0.056089                  0.046695
# bruises                                   0.467305                  0.464709
# odor                                      0.114298                  0.057511
# gill-attachment                           0.087950                  0.117819
# gill-spacing                              0.216872                  0.218085
# gill-size                                 0.057176                  0.010199
# gill-color                                0.226412                  0.258905
# stalk-shape                               0.013132                  0.036317
# stalk-surface-above-ring                  1.000000                  0.437432
# stalk-surface-below-ring                  0.437432                  1.000000
# stalk-color-above-ring                    0.140364                  0.111976
# stalk-color-below-ring                    0.145615                  0.111167
# veil-color                                0.089707                  0.077249
# ring-number                               0.103013                  0.041642
# ring-type                                 0.395711                  0.403007
# spore-print-color                         0.098208                  0.128979
# population                                0.075437                  0.049397
# habitat                                   0.053175                  0.033803
#
#                           stalk-color-above-ring  stalk-color-below-ring  \
# class                                   0.159512                0.150008
# cap-shape                               0.026580                0.031276
# cap-surface                             0.069993                0.077399
# cap-color                               0.004792                0.004713
# bruises                                 0.090104                0.095571
# odor                                    0.177887                0.168892
# gill-attachment                         0.100047                0.098490
# gill-spacing                            0.274687                0.256164
# gill-size                               0.297485                0.279056
# gill-color                              0.057599                0.071640
# stalk-shape                             0.222046                0.231424
# stalk-surface-above-ring                0.140364                0.145615
# stalk-surface-below-ring                0.111976                0.111167
# stalk-color-above-ring                  1.000000                0.493475
# stalk-color-below-ring                  0.493475                1.000000
# veil-color                              0.067513                0.066149
# ring-number                             0.090725                0.087432
# ring-type                               0.045282                0.028736
# spore-print-color                       0.277898                0.255312
# population                              0.246118                0.240885
# habitat                                 0.038827                0.039893
#
#                           veil-color  ring-number  ring-type  \
# class                       0.145333     0.209939   0.416708
# cap-shape                   0.084508     0.105215   0.025194
# cap-surface                 0.016855     0.027691   0.097055
# cap-color                   0.036375     0.007926   0.161881
# bruises                     0.121072     0.051684   0.693453
# odor                        0.058230     0.113845   0.276954
# gill-attachment             0.896781     0.095569   0.145763
# gill-spacing                0.074462     0.249754   0.191458
# gill-size                   0.104510     0.173537   0.459592
# gill-color                  0.097916     0.088361   0.627636
# stalk-shape                 0.162336     0.296435   0.296387
# stalk-surface-above-ring    0.089707     0.103013   0.395711
# stalk-surface-below-ring    0.077249     0.041642   0.403007
# stalk-color-above-ring      0.067513     0.090725   0.045282
# stalk-color-below-ring      0.066149     0.087432   0.028736
# veil-color                  1.000000     0.037072   0.143427
# ring-number                 0.037072     1.000000   0.065201
# ring-type                   0.143427     0.065201   1.000000
# spore-print-color           0.010794     0.342733   0.480412
# population                  0.130068     0.242469   0.204969
# habitat                     0.042361     0.232805   0.218380
#
#                           spore-print-color  population   habitat
# class                              0.173711    0.299936  0.212959
# cap-shape                          0.077272    0.072413  0.040798
# cap-surface                        0.227073    0.016860  0.162217
# cap-color                          0.290393    0.155466  0.030789
# bruises                            0.286756    0.089117  0.086912
# odor                               0.465337    0.041468  0.019540
# gill-attachment                    0.034735    0.172751  0.031777
# gill-spacing                       0.050170    0.528504  0.153027
# gill-size                          0.618708    0.147022  0.165091
# gill-color                         0.417278    0.036907  0.212190
# stalk-shape                        0.256212    0.095550  0.273317
# stalk-surface-above-ring           0.098208    0.075437  0.053175
# stalk-surface-below-ring           0.128979    0.049397  0.033803
# stalk-color-above-ring             0.277898    0.246118  0.038827
# stalk-color-below-ring             0.255312    0.240885  0.039893
# veil-color                         0.010794    0.130068  0.042361
# ring-number                        0.342733    0.242469  0.232805
# ring-type                          0.480412    0.204969  0.218380
# spore-print-color                  1.000000    0.128079  0.192797
# population                         0.128079    1.000000  0.173403
# habitat                            0.192797    0.173403  1.000000
#
# [21 rows x 21 columns]

# %%
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(bool))
upper_triangle
# Out:
#                           class  cap-shape  cap-surface  cap-color   bruises  \
# class                       NaN   0.049545     0.173824   0.040843  0.500526
# cap-shape                   NaN        NaN     0.050648   0.052209  0.033837
# cap-surface                 NaN        NaN          NaN   0.017293  0.081183
# cap-color                   NaN        NaN          NaN        NaN  0.006714
# bruises                     NaN        NaN          NaN        NaN       NaN
# odor                        NaN        NaN          NaN        NaN       NaN
# gill-attachment             NaN        NaN          NaN        NaN       NaN
# gill-spacing                NaN        NaN          NaN        NaN       NaN
# gill-size                   NaN        NaN          NaN        NaN       NaN
# gill-color                  NaN        NaN          NaN        NaN       NaN
# stalk-shape                 NaN        NaN          NaN        NaN       NaN
# stalk-surface-above-ring    NaN        NaN          NaN        NaN       NaN
# stalk-surface-below-ring    NaN        NaN          NaN        NaN       NaN
# stalk-color-above-ring      NaN        NaN          NaN        NaN       NaN
# stalk-color-below-ring      NaN        NaN          NaN        NaN       NaN
# veil-color                  NaN        NaN          NaN        NaN       NaN
# ring-number                 NaN        NaN          NaN        NaN       NaN
# ring-type                   NaN        NaN          NaN        NaN       NaN
# spore-print-color           NaN        NaN          NaN        NaN       NaN
# population                  NaN        NaN          NaN        NaN       NaN
# habitat                     NaN        NaN          NaN        NaN       NaN
#
#                               odor  gill-attachment  gill-spacing  gill-size  \
# class                     0.089666         0.128149      0.345722   0.541694
# cap-shape                 0.027230         0.094725      0.012769   0.050942
# cap-surface               0.042827         0.035221      0.286731   0.206543
# cap-color                 0.384914         0.042563      0.146975   0.166843
# bruises                   0.061789         0.139264      0.299538   0.366131
# odor                           NaN         0.060089      0.063805   0.308160
# gill-attachment                NaN              NaN      0.071985   0.109313
# gill-spacing                   NaN              NaN           NaN   0.107365
# gill-size                      NaN              NaN           NaN        NaN
# gill-color                     NaN              NaN           NaN        NaN
# stalk-shape                    NaN              NaN           NaN        NaN
# stalk-surface-above-ring       NaN              NaN           NaN        NaN
# stalk-surface-below-ring       NaN              NaN           NaN        NaN
# stalk-color-above-ring         NaN              NaN           NaN        NaN
# stalk-color-below-ring         NaN              NaN           NaN        NaN
# veil-color                     NaN              NaN           NaN        NaN
# ring-number                    NaN              NaN           NaN        NaN
# ring-type                      NaN              NaN           NaN        NaN
# spore-print-color              NaN              NaN           NaN        NaN
# population                     NaN              NaN           NaN        NaN
# habitat                        NaN              NaN           NaN        NaN
#
#                           gill-color  ...  stalk-surface-above-ring  \
# class                       0.532084  ...                  0.331843
# cap-shape                   0.002324  ...                  0.034613
# cap-surface                 0.154629  ...                  0.097790
# cap-color                   0.077033  ...                  0.056089
# bruises                     0.526803  ...                  0.467305
# odor                        0.124263  ...                  0.114298
# gill-attachment             0.131314  ...                  0.087950
# gill-spacing                0.097173  ...                  0.216872
# gill-size                   0.514602  ...                  0.057176
# gill-color                       NaN  ...                  0.226412
# stalk-shape                      NaN  ...                  0.013132
# stalk-surface-above-ring         NaN  ...                       NaN
# stalk-surface-below-ring         NaN  ...                       NaN
# stalk-color-above-ring           NaN  ...                       NaN
# stalk-color-below-ring           NaN  ...                       NaN
# veil-color                       NaN  ...                       NaN
# ring-number                      NaN  ...                       NaN
# ring-type                        NaN  ...                       NaN
# spore-print-color                NaN  ...                       NaN
# population                       NaN  ...                       NaN
# habitat                          NaN  ...                       NaN
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# class                                     0.297424                0.159512
# cap-shape                                 0.034984                0.026580
# cap-surface                               0.109499                0.069993
# cap-color                                 0.046695                0.004792
# bruises                                   0.464709                0.090104
# odor                                      0.057511                0.177887
# gill-attachment                           0.117819                0.100047
# gill-spacing                              0.218085                0.274687
# gill-size                                 0.010199                0.297485
# gill-color                                0.258905                0.057599
# stalk-shape                               0.036317                0.222046
# stalk-surface-above-ring                  0.437432                0.140364
# stalk-surface-below-ring                       NaN                0.111976
# stalk-color-above-ring                         NaN                     NaN
# stalk-color-below-ring                         NaN                     NaN
# veil-color                                     NaN                     NaN
# ring-number                                    NaN                     NaN
# ring-type                                      NaN                     NaN
# spore-print-color                              NaN                     NaN
# population                                     NaN                     NaN
# habitat                                        NaN                     NaN
#
#                           stalk-color-below-ring  veil-color  ring-number  \
# class                                   0.150008    0.145333     0.209939
# cap-shape                               0.031276    0.084508     0.105215
# cap-surface                             0.077399    0.016855     0.027691
# cap-color                               0.004713    0.036375     0.007926
# bruises                                 0.095571    0.121072     0.051684
# odor                                    0.168892    0.058230     0.113845
# gill-attachment                         0.098490    0.896781     0.095569
# gill-spacing                            0.256164    0.074462     0.249754
# gill-size                               0.279056    0.104510     0.173537
# gill-color                              0.071640    0.097916     0.088361
# stalk-shape                             0.231424    0.162336     0.296435
# stalk-surface-above-ring                0.145615    0.089707     0.103013
# stalk-surface-below-ring                0.111167    0.077249     0.041642
# stalk-color-above-ring                  0.493475    0.067513     0.090725
# stalk-color-below-ring                       NaN    0.066149     0.087432
# veil-color                                   NaN         NaN     0.037072
# ring-number                                  NaN         NaN          NaN
# ring-type                                    NaN         NaN          NaN
# spore-print-color                            NaN         NaN          NaN
# population                                   NaN         NaN          NaN
# habitat                                      NaN         NaN          NaN
#
#                           ring-type  spore-print-color  population   habitat
# class                      0.416708           0.173711    0.299936  0.212959
# cap-shape                  0.025194           0.077272    0.072413  0.040798
# cap-surface                0.097055           0.227073    0.016860  0.162217
# cap-color                  0.161881           0.290393    0.155466  0.030789
# bruises                    0.693453           0.286756    0.089117  0.086912
# odor                       0.276954           0.465337    0.041468  0.019540
# gill-attachment            0.145763           0.034735    0.172751  0.031777
# gill-spacing               0.191458           0.050170    0.528504  0.153027
# gill-size                  0.459592           0.618708    0.147022  0.165091
# gill-color                 0.627636           0.417278    0.036907  0.212190
# stalk-shape                0.296387           0.256212    0.095550  0.273317
# stalk-surface-above-ring   0.395711           0.098208    0.075437  0.053175
# stalk-surface-below-ring   0.403007           0.128979    0.049397  0.033803
# stalk-color-above-ring     0.045282           0.277898    0.246118  0.038827
# stalk-color-below-ring     0.028736           0.255312    0.240885  0.039893
# veil-color                 0.143427           0.010794    0.130068  0.042361
# ring-number                0.065201           0.342733    0.242469  0.232805
# ring-type                       NaN           0.480412    0.204969  0.218380
# spore-print-color               NaN                NaN    0.128079  0.192797
# population                      NaN                NaN         NaN  0.173403
# habitat                         NaN                NaN         NaN       NaN
#
# [21 rows x 21 columns]

# %%
thereshold = 0.9
to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > thereshold)]
to_drop
# Out:
# []

# %%
corr_matrix = train_data.corr().abs()
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(bool))
thereshold = 0.9
to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > thereshold)]
to_drop
# Out:
# []

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده و احتمالا ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌اید، وقت آن است که مدلی آموزش دهید که بتواند متغیر هدف این مسئله را پیش‌بینی کند.
# </font>
# </p>

# %% [markdown]
# <h3 align=right style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#     استفاده از <code>scikit-learn</code>
# </font>
# </h3>
#
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     الگوریتم <i>جنگل تصادفی</i> با نام <code>RandomForestClassifier</code> در پکیج <code>ensemble</code> این کتابخانه در دسترس است. برخی از آرگومان‌های مهم آن در جدول زیر آمده است، اما جهت مطالعه‌ی کامل‌تر مستندات می‌توانید به <a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html" target="_blank">این لینک</a> مراجعه فرمایید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |آرگومان|توضیحات|
# |:------:|:---:|
# |<code>n_estimators</code>|تعداد درخت جنگل|
# |<code>max_depth</code>|حداکثر عمق یک درخت|
# |<code>bootstrap</code>|آیا از تکنیک بوت‌استرپ در هنگام ساخت درخت استفاده شود یا خیر. اگر معادل <code>False</code> تنظیم شود از کل مجموعه‌داده استفاده خواهد شد.|
# |<code>oob_score</code>|آیا از نمونه‌های خارج از بگ جهت ارزیابی استفاده شود یا خیر. تنها در صورتی که <code>bootstrap</code> معادل <code>True</code> تنظیم شده باشد.|
# |<code>max_samples</code>|تعداد نمونه‌هایی که در بوت‌استرپ از مجموعه‌داده انتخاب می‌شود تا به کمک آن یک درخت تولید گردد.|
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در سلول زیر با استفاده از مدل آماده‌ای که در بالا شرح داده شد و به کمک تابع <code>fit</code> الگوریتم را بر روی مجموعه‌ی آموزشی اجرا کنید.
# </font>
# </p>

# %%
y = train_data['class']
X = train_data.drop('class', axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2, random_state = 43)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators= 100,
    max_depth = None,
    bootstrap = True,
    oob_score = True
    
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(oob_score=True)

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     از آنجا که تشخیص اشتباه یک قارچ سمی به عنوان خوراکی می‌تواند منجر به مرگ شخصی شود، باید سعی کنیم به مدلی دست یابیم که تا حد ممکن قارچی را که سمی است به اشتباه خوراکی تشخیص ندهد. به بیان دیگر <code>tn</code> در این مسئله اهمیت بالایی دارد. به همین دلیل معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، معیار <code>Recall</code> است.
#     <br>
#     این معیار، سنجه ارزیابی کیفیت مدل شماست. به عبارت بهتر در سامانه داوری هم از همین معیار برای نمره‌دهی استفاده شده است.
#     <br>
#     پیشنهاد می‌شود با توجه به این معیار، عملکرد مدل خود را بر روی مجموعه‌ی آموزش یا اعتبارسنجی ارزیابی کنید.
#     <br>
#     برای محاسبه‌ی عملکرد مدل طبق این معیار می‌توانید از <code>sklearn.metrics.recall_score</code> استفاده کرده و از آنجا که قصد داریم دسته‌ی سمی را برابر کلاس مثبت در نظر بگیریم نیاز است تا آرگومان <code>pos_label</code> را معادل برچسب مربوط به کلاس سمی تنظیم کنید. جهت مطالعه‌ی مستندات این کلاس می‌توانید به <a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html" target="_blank">این لینک</a> مراجعه فرمایید.
# </font>
# </p>

# %% [markdown]
# $$Recall=\frac{tp}{tp+fn}$$

# %% [markdown]
# # evaluate your model

# %%
from sklearn.metrics import recall_score

y_pred = model.predict(X_val)
recall_score(y_val, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred)
# Out:
# array([[678,   0],
#        [  0, 622]], dtype=int64)

# %%
from sklearn.metrics import precision_score
precision_score(y_val, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       678
#            1       1.00      1.00      1.00       622
#
#     accuracy                           1.00      1300
#    macro avg       1.00      1.00      1.00      1300
# weighted avg       1.00      1.00      1.00      1300

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما امتیاز <code>100</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     پس از مهندسی ویژگی و مدل‌سازی، الگوریتمی دارید که می‌تواند شما را از متغیرهای مستقل به متغیر هدف برساند.
#     <br>
#     از این مدل برای پیش‌بینی نمونه‌های موجود در داده تست استفاده کنید و نتایج را در قالب جدول زیر آماده کنید.
# </font>
# </p>

# %% [markdown]
# <center>
# <div dir=rtl style="line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>class</code>|برچسب پیش‌بینی‌شده (سمی یا خوراکی)|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     توجه داده باشید که نوع قارچ را باید همچون مجموعه‌داده‌ی اولیه یعنی بصورت کاراکتر (<code>p</code> یا <code>e</code>) درج کنید.
# </font>
# </p>

# %%
y_pred_test = model.predict(test_data)

# %%
# predict test samples
prediction = pd.DataFrame()
prediction['class'] = y_pred_test

# %%
prediction.head()
# Out:
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
prediction.value_counts()
# Out:
# class
# 0        821
# 1        804
# Name: count, dtype: int64

# %%
prediction['class'] = prediction['class'].replace({1: 'p', 0: 'e'})
prediction
# Out:
#      class
# 0        e
# 1        e
# 2        e
# 3        e
# 4        e
# ...    ...
# 1620     p
# 1621     p
# 1622     p
# 1623     p
# 1624     p
#
# [1625 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

joblib.dump(model, 'model')
prediction.to_csv('submission.csv', index=False)
file_names = ['mushroom_hunter.ipynb', 'submission.csv', 'model']
compress(file_names)
